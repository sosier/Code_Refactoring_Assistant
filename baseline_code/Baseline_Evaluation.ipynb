# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

from multiprocess import Pool
import pandas as pd
import pickle

# Expects this file and eval.py to be in the same folder:
from eval import DATA, evaluate, bulk_evaluate

mbpp = DATA["mbpp"]  # train, validation, and test
humaneval = DATA["openai_humaneval"]  # test only

# %% [markdown]
# ## Helpers

# %%
RESULTS_PATH = "./results/"

def save_pickle(object, to):
    with open(to, "wb") as f:
        pickle.dump(object, f)
    
def load_pickle(from_):
    with open(from_, "rb") as f:
        return pickle.load(f)

def check_results_for_errors(results, result_ids):
    print(len(results))
    errors = [i for i, result in zip(result_ids, results) if result == "ERROR"]
    print(len(errors))
    return errors

# %% [markdown]
# ## HumanEval

# %%
canonical_solutions = [
    task["prompt"] + task["canonical_solution"] for task in humaneval["test"]
]
print(len(canonical_solutions))

results = bulk_evaluate(
    dataset="openai_humaneval",
    split="test",
    code=canonical_solutions,
    num_processes=10
)
print(len(results))
save_pickle(results, RESULTS_PATH + "openai_humaneval_test_results_1.pkl")

errors = check_results_for_errors(results, result_ids=range(len(results)))
errors  # If any errors (e.g. from timeouts) may need to re-run some evaluations

# %%
# Assuming no errors
df = pd.DataFrame(results)
df.insert(3, "model", "canonical_solution")
df.insert(4, "code", canonical_solutions)
df
# Out:
#               dataset split  task_id               model  \
# 0    openai_humaneval  test        0  canonical_solution
# 1    openai_humaneval  test        1  canonical_solution
# 2    openai_humaneval  test        2  canonical_solution
# 3    openai_humaneval  test        3  canonical_solution
# 4    openai_humaneval  test        4  canonical_solution
# ..                ...   ...      ...                 ...
# 159  openai_humaneval  test      159  canonical_solution
# 160  openai_humaneval  test      160  canonical_solution
# 161  openai_humaneval  test      161  canonical_solution
# 162  openai_humaneval  test      162  canonical_solution
# 163  openai_humaneval  test      163  canonical_solution
#
#                                                   code  result  avg_test_time  \
# 0    from typing import List\n\n\ndef has_close_ele...  passed       0.000203
# 1    from typing import List\n\n\ndef separate_pare...  passed       0.000093
# 2    \n\ndef truncate_number(number: float) -> floa...  passed       0.000058
# 3    from typing import List\n\n\ndef below_zero(op...  passed       0.000130
# 4    from typing import List\n\n\ndef mean_absolute...  passed       0.000101
# ..                                                 ...     ...            ...
# 159  \ndef eat(number, need, remaining):\n    """\n...  passed       0.000118
# 160  \ndef do_algebra(operator, operand):\n    """\...  passed       0.000122
# 161  \ndef solve(s):\n    """You are given a string...  passed       0.000089
# 162  \ndef string_to_md5(text):\n    """\n    Given...  passed       0.000063
# 163  \ndef generate_integers(a, b):\n    """\n    G...  passed       0.000089
#
#      passed_tests  compiled  loc  ...  N2  vocabulary  length  \
# 0            True      True   19  ...   6           9       9
# 1            True      True   28  ...  10           9      15
# 2            True      True   12  ...   2           3       3
# 3            True      True   20  ...   4           5       6
# 4            True      True   14  ...   6           8       9
# ..            ...       ...  ...  ...  ..         ...     ...
# 159          True      True   34  ...   8           6      12
# 160          True      True   30  ...   4           5       6
# 161          True      True   26  ...   7           9      11
# 162          True      True   10  ...   0           0       0
# 163          True      True   15  ...   6           9       9
#
#      calculated_length     volume  difficulty      effort      time      bugs  \
# 0            20.264663  28.529325    1.500000   42.793988  2.377444  0.009510
# 1            20.264663  47.548875    2.500000  118.872188  6.604010  0.015850
# 2             2.000000   4.754888    0.500000    2.377444  0.132080  0.001585
# 3             6.754888  13.931569    1.333333   18.575425  1.031968  0.004644
# 4            17.509775  27.000000    1.000000   27.000000  1.500000  0.009000
# ..                 ...        ...         ...         ...       ...       ...
# 159           9.509775  31.019550    4.000000  124.078200  6.893233  0.010340
# 160           8.000000  13.931569    0.500000    6.965784  0.386988  0.004644
# 161          20.264663  34.869175    1.750000   61.021056  3.390059  0.011623
# 162           0.000000   0.000000    0.000000    0.000000  0.000000  0.000000
# 163          20.264663  28.529325    1.500000   42.793988  2.377444  0.009510
#
#              MI
# 0     95.605923
# 1     89.398652
# 2     65.110353
# 3     96.412688
# 4     80.591775
# ..          ...
# 159   43.507133
# 160   50.101277
# 161   90.712125
# 162  100.000000
# 163   80.289730
#
# [164 rows x 30 columns]

# %%
# Finally, when everything looks good save the data. Will overwrite previously
# saved data at this location. Be sure you want to do this!
# df.to_csv(RESULTS_PATH + "openai_humaneval_test_cannonical.csv")

# %% [markdown]
# ## MBPP Test

# %%
canonical_solutions = [
    "# " + task["text"] + "\n" + task["code"] for task in mbpp["test"]
]
print(len(canonical_solutions))

results = bulk_evaluate(
    dataset="mbpp",
    split="test",
    code=canonical_solutions,
    num_processes=10
)
print(len(results))
save_pickle(results, RESULTS_PATH + "mbpp_test_results_1.pkl")

errors = check_results_for_errors(results, result_ids=range(len(results)))
errors  # If any errors (e.g. from timeouts) may need to re-run some evaluations

# %%
# Assuming no errors
df = pd.DataFrame(results)
df.insert(3, "model", "canonical_solution")
df.insert(4, "code", canonical_solutions)
df
# Out:
#     dataset split  task_id               model  \
# 0      mbpp  test        0  canonical_solution
# 1      mbpp  test        1  canonical_solution
# 2      mbpp  test        2  canonical_solution
# 3      mbpp  test        3  canonical_solution
# 4      mbpp  test        4  canonical_solution
# ..      ...   ...      ...                 ...
# 495    mbpp  test      495  canonical_solution
# 496    mbpp  test      496  canonical_solution
# 497    mbpp  test      497  canonical_solution
# 498    mbpp  test      498  canonical_solution
# 499    mbpp  test      499  canonical_solution
#
#                                                   code  result  avg_test_time  \
# 0    # Write a python function to remove first and ...  passed       0.000058
# 1    # Write a function to sort a given matrix in a...  passed       0.000129
# 2    # Write a function to count the most common wo...  passed       0.000197
# 3    # Write a python function to find the volume o...  passed       0.000033
# 4    # Write a function to split a string at lowerc...  passed       0.000057
# ..                                                 ...     ...            ...
# 495  # Write a function to calculate the permutatio...  passed       0.000072
# 496  # Write a function to remove specific words fr...  passed       0.000102
# 497  # Write a function to check if the common elem...  passed       0.000079
# 498  # Write a python function to find the average ...  passed       0.000025
# 499  # Write a function to find the number of subse...  passed       0.000171
#
#      passed_tests  compiled  loc  ...  N2  vocabulary  length  \
# 0            True      True   11  ...  16          14      25
# 1            True      True    4  ...   0           0       0
# 2            True      True    6  ...   0           0       0
# 3            True      True    3  ...   6           8       9
# 4            True      True    4  ...   0           0       0
# ..            ...       ...  ...  ...  ..         ...     ...
# 495          True      True   14  ...  24          15      36
# 496          True      True    6  ...   2           3       3
# 497          True      True    6  ...   8           9      12
# 498          True      True   12  ...  15          14      23
# 499          True      True   11  ...  30          20      45
#
#      calculated_length      volume  difficulty       effort       time  \
# 0            41.219281   95.183873    3.200000   304.588394  16.921577
# 1             0.000000    0.000000    0.000000     0.000000   0.000000
# 2             0.000000    0.000000    0.000000     0.000000   0.000000
# 3            17.509775   27.000000    1.000000    27.000000   1.500000
# 4             0.000000    0.000000    0.000000     0.000000   0.000000
# ..                 ...         ...         ...          ...        ...
# 495          44.828921  140.648061    6.000000   843.888369  46.882687
# 496           2.000000    4.754888    0.500000     2.377444   0.132080
# 497          20.264663   38.039100    2.000000    76.078200   4.226567
# 498          39.302969   87.569163    7.500000   656.768724  36.487151
# 499          68.812744  194.486764    6.428571  1250.272056  69.459559
#
#          bugs          MI
# 0    0.031728   79.749780
# 1    0.000000  100.000000
# 2    0.000000  100.000000
# 3    0.009000  100.000000
# 4    0.000000  100.000000
# ..        ...         ...
# 495  0.046883   77.194341
# 496  0.001585  100.000000
# 497  0.012680   96.396081
# 498  0.029190   80.381523
# 499  0.064829   80.033272
#
# [500 rows x 30 columns]

# %%
# Finally, when everything looks good save the data. Will overwrite previously
# saved data at this location. Be sure you want to do this!
# df.to_csv(RESULTS_PATH + "mbpp_test_cannonical.csv")

# %% [markdown]
# ## MBPP Train

# %%
canonical_solutions = [
    "# " + task["text"] + "\n" + task["code"] for task in mbpp["train"]
]
print(len(canonical_solutions))

results = bulk_evaluate(
    dataset="mbpp",
    split="train",
    code=canonical_solutions,
    num_processes=10
)
print(len(results))
save_pickle(results, RESULTS_PATH + "mbpp_train_results_1.pkl")

errors = check_results_for_errors(results, result_ids=range(len(results)))
errors  # If any errors (e.g. from timeouts) may need to re-run some evaluations

# %%
# Assuming no errors
df = pd.DataFrame(results)
df.insert(3, "model", "canonical_solution")
df.insert(4, "code", canonical_solutions)
df
# Out:
#     dataset  split  task_id               model  \
# 0      mbpp  train        0  canonical_solution
# 1      mbpp  train        1  canonical_solution
# 2      mbpp  train        2  canonical_solution
# 3      mbpp  train        3  canonical_solution
# 4      mbpp  train        4  canonical_solution
# ..      ...    ...      ...                 ...
# 369    mbpp  train      369  canonical_solution
# 370    mbpp  train      370  canonical_solution
# 371    mbpp  train      371  canonical_solution
# 372    mbpp  train      372  canonical_solution
# 373    mbpp  train      373  canonical_solution
#
#                                                   code  result  compiled  \
# 0    # Write a function to find the longest chain w...  passed      True
# 1    # Write a python function to find the first re...  passed      True
# 2    # Write a function to get a lucid number small...  passed      True
# 3    # Write a function to reverse words in a given...  passed      True
# 4    # Write a function to check if the given integ...  passed      True
# ..                                                 ...     ...       ...
# 369  # Write a function to find minimum of two numb...  passed      True
# 370  # Write a function to find the maximum number ...  passed      True
# 371  # Write a function to concatenate the given tw...  passed      True
# 372  # Write a python function to left rotate the s...  passed      True
# 373  # Write a function to find the minimum total p...  passed      True
#
#      passed_tests  avg_test_time  loc  ...  N2  vocabulary  length  \
# 0            True       0.000107   17  ...  12          15      18
# 1            True       0.000029    6  ...   4           5       6
# 2            True       0.000084   14  ...  14          12      21
# 3            True       0.000032    3  ...   0           0       0
# 4            True       0.000026   10  ...   8          10      12
# ..            ...            ...  ...  ...  ..         ...     ...
# 369          True       0.000029    5  ...   2           3       3
# 370          True       0.000055   16  ...  38          22      58
# 371          True       0.000063    4  ...   2           3       3
# 372          True       0.000031    4  ...   2           3       3
# 373          True       0.000069   11  ...  12          13      19
#
#      calculated_length      volume  difficulty       effort       time  \
# 0            46.053748   70.324031    2.181818   153.434249   8.524125
# 1             6.754888   13.931569    1.333333    18.575425   1.031968
# 2            32.000000   75.284213    3.500000   263.494744  14.638597
# 3             0.000000    0.000000    0.000000     0.000000   0.000000
# 4            23.509775   39.863137    2.666667   106.301699   5.905650
# ..                 ...         ...         ...          ...        ...
# 369           2.000000    4.754888    0.500000     2.377444   0.132080
# 370          81.096509  258.647034    5.588235  1445.380483  80.298916
# 371           2.000000    4.754888    0.500000     2.377444   0.132080
# 372           2.000000    4.754888    0.500000     2.377444   0.132080
# 373          36.529325   70.308355    2.666667   187.488946  10.416053
#
#          bugs          MI
# 0    0.023441   74.679196
# 1    0.004644   99.719576
# 2    0.025095   77.915787
# 3    0.000000  100.000000
# 4    0.013288   86.066773
# ..        ...         ...
# 369  0.001585  100.000000
# 370  0.086216   73.665796
# 371  0.001585  100.000000
# 372  0.001585  100.000000
# 373  0.023436   83.530852
#
# [374 rows x 30 columns]

# %%
# Finally, when everything looks good save the data. Will overwrite previously
# saved data at this location. Be sure you want to do this!
# df.to_csv(RESULTS_PATH + "mbpp_train_cannonical.csv")

# %% [markdown]
# ## MBPP Validate

# %%
canonical_solutions = [
    "# " + task["text"] + "\n" + task["code"] for task in mbpp["validation"]
]
print(len(canonical_solutions))

results = bulk_evaluate(
    dataset="mbpp",
    split="validation",
    code=canonical_solutions,
    num_processes=10
)
print(len(results))
save_pickle(results, RESULTS_PATH + "mbpp_validation_results_1.pkl")

errors = check_results_for_errors(results, result_ids=range(len(results)))
errors  # If any errors (e.g. from timeouts) may need to re-run some evaluations

# %%
# Assuming no errors
df = pd.DataFrame(results)
df.insert(3, "model", "canonical_solution")
df.insert(4, "code", canonical_solutions)
df
# Out:
#    dataset       split  task_id               model  \
# 0     mbpp  validation        0  canonical_solution
# 1     mbpp  validation        1  canonical_solution
# 2     mbpp  validation        2  canonical_solution
# 3     mbpp  validation        3  canonical_solution
# 4     mbpp  validation        4  canonical_solution
# ..     ...         ...      ...                 ...
# 85    mbpp  validation       85  canonical_solution
# 86    mbpp  validation       86  canonical_solution
# 87    mbpp  validation       87  canonical_solution
# 88    mbpp  validation       88  canonical_solution
# 89    mbpp  validation       89  canonical_solution
#
#                                                  code  result  avg_test_time  \
# 0   # Write a python function to find minimum sum ...  passed       0.000034
# 1   # Write a function to count the element freque...  passed       0.000113
# 2   # Write a function to convert tuple into list ...  passed       0.000091
# 3   # Write a function to find the summation of tu...  passed       0.000048
# 4   # Write a function to check if there is a subs...  passed       0.000061
# ..                                                ...     ...            ...
# 85  # Write a function to find the size of the giv...  passed       0.000111
# 86  # Write a function to find kth element from th...  passed       0.000102
# 87  # Write a function to check whether the given ...  passed       0.000029
# 88  # Write a function to find sum and average of ...  passed       0.000038
# 89  # Write a python function to check whether the...  passed       0.000028
#
#     passed_tests  compiled  loc  ...  N2  vocabulary  length  \
# 0           True      True   11  ...  16          13      24
# 1           True      True   14  ...   4           6       6
# 2           True      True    4  ...   0           0       0
# 3           True      True    4  ...   0           0       0
# 4           True      True   18  ...  16          16      24
# ..           ...       ...  ...  ...  ..         ...     ...
# 85          True      True    4  ...   0           0       0
# 86          True      True   23  ...  32          18      48
# 87          True      True   17  ...  18          15      27
# 88          True      True    7  ...   6           6       9
# 89          True      True    6  ...   6           7       9
#
#     calculated_length      volume  difficulty       effort       time  \
# 0           35.161259   88.810553    6.857143   608.986651  33.832592
# 1           10.000000   15.509775    1.000000    15.509775   0.861654
# 2            0.000000    0.000000    0.000000     0.000000   0.000000
# 3            0.000000    0.000000    0.000000     0.000000   0.000000
# 4           51.019550   96.000000    2.666667   256.000000  14.222222
# ..                ...         ...         ...          ...        ...
# 85           0.000000    0.000000    0.000000     0.000000   0.000000
# 86          59.715357  200.156400    6.153846  1231.731693  68.429538
# 87          44.039100  105.486046    6.000000   632.916276  35.162015
# 88          10.000000   23.264663    1.500000    34.896994   1.938722
# 89          12.754888   25.266194    2.250000    56.848937   3.158274
#
#         bugs          MI
# 0   0.029604   81.956795
# 1   0.005170   82.585354
# 2   0.000000  100.000000
# 3   0.000000  100.000000
# 4   0.032000   71.883363
# ..       ...         ...
# 85  0.000000  100.000000
# 86  0.066719   66.296343
# 87  0.035162   73.507300
# 88  0.007755   95.075198
# 89  0.008422   98.043780
#
# [90 rows x 30 columns]

# %%
# Finally, when everything looks good save the data. Will overwrite previously
# saved data at this location. Be sure you want to do this!
# df.to_csv(RESULTS_PATH + "mbpp_validation_cannonical.csv")
